# %% [markdown]
# # Applied Data Science Capstone

# %% [markdown]
# This notebook hosts code for Applied Data Science Capstone project

# %% [markdown]
# ### Week 1 - Capstone Project Notebook

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# ### Week 3 - Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# **Step 1**: prepare environment

# %%
import requests

# %% [markdown]
# **Step 2:** get wiki page as text

# %%
wiki_url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wiki_page = requests.get(wiki_url)

# %% [markdown]
# **Step 3:** extract table by class to dataframe

# %%
codes_df_list = pd.read_html(io = wiki_page.text, attrs = {'class': 'wikitable'})
codes_df_0 = codes_df_list[0]

# %%
codes_df_0.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor
# 7      M7A  Downtown Toronto      Queen's Park
# 8      M8A      Not assigned      Not assigned
# 9      M9A      Queen's Park      Not assigned

# %% [markdown]
# **Step 4:** rename column

# %%
codes_df_1 = codes_df_0.rename(columns = {'Postcode': 'PostalCode'})

# %%
codes_df_1.head(10)
# Out:
#   PostalCode           Borough     Neighbourhood
# 0        M1A      Not assigned      Not assigned
# 1        M2A      Not assigned      Not assigned
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront
# 5        M6A        North York  Lawrence Heights
# 6        M6A        North York    Lawrence Manor
# 7        M7A  Downtown Toronto      Queen's Park
# 8        M8A      Not assigned      Not assigned
# 9        M9A      Queen's Park      Not assigned

# %% [markdown]
# **Step 5:** remove Borough 'Not Assigned' values

# %%
codes_df_2 = codes_df_1[codes_df_1['Borough'] != 'Not assigned']

# %%
codes_df_2.head(10)
# Out:
#    PostalCode           Borough     Neighbourhood
# 2         M3A        North York         Parkwoods
# 3         M4A        North York  Victoria Village
# 4         M5A  Downtown Toronto      Harbourfront
# 5         M6A        North York  Lawrence Heights
# 6         M6A        North York    Lawrence Manor
# 7         M7A  Downtown Toronto      Queen's Park
# 9         M9A      Queen's Park      Not assigned
# 10        M1B       Scarborough             Rouge
# 11        M1B       Scarborough           Malvern
# 13        M3B        North York   Don Mills North

# %% [markdown]
# **Step 6:** fill 'Not assigned' neighborhood with borough

# %%
codes_df_2['Neighbourhood'] = np.where(codes_df_2['Neighbourhood'] == 'Not assigned', codes_df_2['Borough'], codes_df_2['Neighbourhood'])
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
codes_df_2.head(10)
# Out:
#    PostalCode           Borough     Neighbourhood
# 2         M3A        North York         Parkwoods
# 3         M4A        North York  Victoria Village
# 4         M5A  Downtown Toronto      Harbourfront
# 5         M6A        North York  Lawrence Heights
# 6         M6A        North York    Lawrence Manor
# 7         M7A  Downtown Toronto      Queen's Park
# 9         M9A      Queen's Park      Queen's Park
# 10        M1B       Scarborough             Rouge
# 11        M1B       Scarborough           Malvern
# 13        M3B        North York   Don Mills North

# %% [markdown]
# **Step 7:** combine neighborhoods with same postal code area

# %%
aggr_df = codes_df_2.groupby(['PostalCode', 'Borough'])['Neighbourhood'].apply(lambda v: ', '.join(v)).reset_index()

# %% [markdown]
# **Step 8:** check result dataframe

# %%
aggr_df.shape
# Out:
# (103, 3)

# %% [markdown]
# **Step 9:** enhance environment

# %%
import sys
# !{sys.executable} -m pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 6.6MB/s ta 0:00:011
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: future in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: click in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (7.0)
# Requirement already satisfied: decorator in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (1.24.1)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
import geocoder

# %% [markdown]
# **Step 10:** try to get data from geocoder

# %%
def get_lat_lon(postal_code):
    lat_lng_coords = None
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
    return [lat_lng_coords[0], lat_lng_coords[1]]
#latitude = lat_lng_coords[0]
#longitude = lat_lng_coords[1]

# %%
lat_list = []
lon_list = []
pc_list = aggr_df['PostalCode'].tolist()
for pc in pc_list:
    lat_lon = get_lat_lon(pc)
    lat.apend(lat_lon[0])
    lon.append(lat_lon[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-9d8637b2a943> in <module>
#       3 pc_list = aggr_df['PostalCode'].tolist()
#       4 for pc in pc_list:
# ----> 5     lat_lon = get_lat_lon(pc)
#       6     lat.apend(lat_lon[0])
#       7     lon.append(lat_lon[1])
#
# <ipython-input-18-125419a665d4> in get_lat_lon(postal_code)
#       2     lat_lng_coords = None
#       3     while(lat_lng_coords is None):
# ----> 4         g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#       5         lat_lng_coords = g.latlng
#       6     return [lat_lng_coords[0], lat_lng_coords[1]]
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geocoder/api.py in google(location, **kwargs)
#     230         > elevation
#     231     """
# --> 232     return get(location, provider='google', **kwargs)
#     233
#     234
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geocoder/api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geocoder/base.py in __init__(self, location, **kwargs)
#     408
#     409         # query and parse results
# --> 410         self._initialize()
#     411
#     412     def __getitem__(self, key):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geocoder/base.py in _initialize(self)
#     455     def _initialize(self):
#     456         # query URL and get valid JSON (also stored in self.json)
# --> 457         json_response = self._connect()
#     458
#     459         # catch errors
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geocoder/base.py in _connect(self)
#     482                 headers=self.headers,
#     483                 timeout=self.timeout,
# --> 484                 proxies=self.proxies
#     485             )
#     486
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geocoder/google.py in rate_limited_get(self, *args, **kwargs)
#     267             return self.rate_limited_get_for_work(*args, **kwargs)
#     268         else:
# --> 269             return self.rate_limited_get_for_dev(*args, **kwargs)
#     270
#     271     @ratelim.greedy(2500, 60 * 60 * 24)
#
# </opt/conda/envs/Python36/lib/python3.6/site-packages/decorator.py:decorator-gen-127> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ratelim/__init__.py in wrapped_f(self, f, *args, **kwargs)
#      36
#      37         self.__numcalls += 1
# ---> 38         return f(*args, **kwargs)
#      39
#      40     def __call__(self, f, *args, **kwargs):
#
# </opt/conda/envs/Python36/lib/python3.6/site-packages/decorator.py:decorator-gen-126> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ratelim/__init__.py in wrapped_f(self, f, *args, **kwargs)
#      36
#      37         self.__numcalls += 1
# ---> 38         return f(*args, **kwargs)
#      39
#      40     def __call__(self, f, *args, **kwargs):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geocoder/google.py in rate_limited_get_for_dev(self, *args, **kwargs)
#     272     @ratelim.greedy(10, 1)
#     273     def rate_limited_get_for_dev(self, *args, **kwargs):
# --> 274         return super(GoogleQuery, self).rate_limited_get(*args, **kwargs)
#     275
#     276     @ratelim.greedy(100000, 60 * 60 * 24)  # Google for Work daily limit
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geocoder/base.py in rate_limited_get(self, url, **kwargs)
#     508     def rate_limited_get(self, url, **kwargs):
#     509         """ By default, simply wraps a session.get request"""
# --> 510         return self.session.get(url, **kwargs)
#     511
#     512     def _adapt_results(self, json_response):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /opt/conda/envs/Python36/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /opt/conda/envs/Python36/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /opt/conda/envs/Python36/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /opt/conda/envs/Python36/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# **Step 11:** geocoder does not work, use csv data

# %%
geo_df = pd.read_csv('https://cocl.us/Geospatial_data')

# %% [markdown]
# **Step 12:** prepare geo data to merge into neigborhoods data

# %%
geo_df_merge = geo_df.rename(columns = {'Postal Code': 'PostalCode'}, )

# %%
geo_df_merge.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %% [markdown]
# **Step 13:** merge geo data

# %%
data_with_geo = pd.merge(aggr_df, geo_df_merge[['PostalCode', 'Latitude', 'Longitude']], on = 'PostalCode')

# %% [markdown]
# **Step 14:** check data

# %%
data_with_geo.head()
# Out:
#   PostalCode      Borough                           Neighbourhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
data_with_geo['Borough'].unique().tolist()
# Out:
# ['Scarborough',
#  'North York',
#  'East York',
#  'East Toronto',
#  'Central Toronto',
#  'Downtown Toronto',
#  'York',
#  'West Toronto',
#  'Mississauga',
#  'Etobicoke',
#  "Queen's Park"]

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# **Step 15:** envance environment vol.2

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.3.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# **Step 16:** get Toronto coordinates

# %%
geolocator = Nominatim(user_agent='foursquare_agent')
location = geolocator.geocode('Toronto, Canada')
tor_lat = location.latitude
tor_lon = location.longitude
print(tor_lat, tor_lon)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# **Step 17:** define color map

# %%
bor_col = {
     'East Toronto': 'red',
     'Central Toronto': 'green',
     'Downtown Toronto': 'blue',
     'West Toronto': 'yellow'
}

# %% [markdown]
# **Step 18:** select only Toronto's boroughs

# %%
tor_bor = data_with_geo[data_with_geo['Borough'].str.contains('Toronto')]

# %%
tor_bor.head()
# Out:
#    PostalCode          Borough                   Neighbourhood   Latitude  \
# 37        M4E     East Toronto                     The Beaches  43.676357
# 41        M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 42        M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 43        M4M     East Toronto                 Studio District  43.659526
# 44        M4N  Central Toronto                   Lawrence Park  43.728020
#
#     Longitude
# 37 -79.293031
# 41 -79.352188
# 42 -79.315572
# 43 -79.340923
# 44 -79.388790

# %%
tor_bor.shape
# Out:
# (39, 5)

# %%
tor_map = folium.Map(location=[tor_lat, tor_lon], zoom_start=11)

for lat, lng, borough in zip(tor_bor['Latitude'], tor_bor['Longitude'], tor_bor['Borough']):
    label = borough
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color=bor_col.get(borough),
#         fill=True,
#         fill_color=bor_col.get(borough),
#         fill_opacity=0.5,
        parse_html=False).add_to(tor_map)
    
tor_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Step 19:** additional data

# %%
# 1 degree of latitude ~ 111 km
lat_dist = 111000
# 1 degree of longitude ~ 81 km at Toronto latitude
lon_dist = 81000

# %% [markdown]
# **Step 20:** cluster neighborhoods

# %% [markdown]
# cluster and visualize neighborhoods of Toronto
# as it seen from map, we have 4 boroughs

# %%
k_tor_cl = 4

# %% [markdown]
# try to get borough's coordinates to ease clustering

# %%
bor_lat_lon = []
for bor in bor_col:
    location = geolocator.geocode(bor + ', Toronto, Canada')
    lat = location.latitude
    lon = location.longitude
    bor_lat_lon.append({'Borough': bor, 'Latitude': lat, 'Longitude': lon})
df_tor_bor = pd.DataFrame(bor_lat_lon)
df_tor_bor.head()
# Out:
#             Borough   Latitude  Longitude
# 0      East Toronto  43.624790 -79.393492
# 1   Central Toronto  43.653963 -79.387207
# 2  Downtown Toronto  43.656322 -79.380916
# 3      West Toronto  43.653963 -79.387207

# %%
tor_bor_map = folium.Map(location=[tor_lat, tor_lon], zoom_start=11)

for lat, lng, borough in zip(df_tor_bor['Latitude'], df_tor_bor['Longitude'], df_tor_bor['Borough']):
    label = borough
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=50,
        popup=label,
        color=bor_col.get(borough),
#         fill=True,
#         fill_color=bor_col.get(borough),
#         fill_opacity=0.5,
        parse_html=False).add_to(tor_bor_map)
    
tor_bor_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# after visualization we can see that geo data is misplacing borougs, so we use clustering and take these as initial points

# %% [markdown]
# **Step 21:** additional functions

# %%
import math

def get_distance(lat1, lon1, lat2, lon2):
    lat_delta = lat1 - lat2
    lon_delta = lon1 - lon2
    y = lat_delta * lat_dist
    x = lon_delta * lon_dist
    dist = math.sqrt(x * x + y * y)
    return(dist)

def assign_members(lat, lon, nbh, test_df):
    dist_min = 1000000
    bor = ''
    for index, row in df_tor_bor.iterrows():
        dist = get_distance(row['Latitude'], row['Longitude'], lat, lon)
        if dist < dist_min:
            dist_min = dist
            bor = row['Borough']
    test_df.loc[len(test_df)] = [bor, nbh, lat, lon]

# %% [markdown]
# **Step 23:** assign beigborhoods to boroughs using geo k-centers

# %%
knn_df = pd.DataFrame(columns = ['Borough', 'Neighbourhood', 'Latitude', 'Longitude'])
for index, row in tor_bor.reset_index().iterrows():
    assign_members(row['Latitude'], row['Longitude'], row['Neighbourhood'], knn_df)
knn_df.head()
# knn_df.shape
# Out:
#             Borough                   Neighbourhood   Latitude  Longitude
# 0  Downtown Toronto                     The Beaches  43.676357 -79.293031
# 1  Downtown Toronto    The Danforth West, Riverdale  43.679557 -79.352188
# 2  Downtown Toronto  The Beaches West, India Bazaar  43.668999 -79.315572
# 3  Downtown Toronto                 Studio District  43.659526 -79.340923
# 4  Downtown Toronto                   Lawrence Park  43.728020 -79.388790

# %% [markdown]
# **Step 24:** visualize

# %%
k_temp_map = folium.Map(location=[tor_lat, tor_lon], zoom_start=11)

for lat, lng, borough in zip(knn_df['Latitude'], knn_df['Longitude'], knn_df['Borough']):
    label = borough
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color=bor_col.get(borough),
#         fill=True,
#         fill_color=bor_col.get(borough),
#         fill_opacity=0.5,
        parse_html=False).add_to(k_temp_map)
    
k_temp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# we will use mean coordinates to determine borough cluster centers

# %%
tor_bor_lat_lon = tor_bor.drop(['PostalCode', 'Neighbourhood'], axis = 1)
tor_bor_lat_lon_mean = tor_bor_lat_lon.groupby('Borough').mean().reset_index()
tor_bor_lat_lon_mean.head()
# Out:
#             Borough   Latitude  Longitude
# 0   Central Toronto  43.701980 -79.398954
# 1  Downtown Toronto  43.654597 -79.383972
# 2      East Toronto  43.669436 -79.324654
# 3      West Toronto  43.652653 -79.449290

# %% [markdown]
# put new data on map

# %%
tor_bor_lat_lon = folium.Map(location=[tor_lat, tor_lon], zoom_start=11)

for lat, lng, borough in zip(tor_bor_lat_lon_mean['Latitude'], tor_bor_lat_lon_mean['Longitude'], tor_bor_lat_lon_mean['Borough']):
    label = borough
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color=bor_col.get(borough),
#         fill=True,
#         fill_color=bor_col.get(borough),
#         fill_opacity=0.5,
        parse_html=False).add_to(tor_bor_lat_lon)
    
tor_bor_lat_lon
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# put new centers to work

# %%
def assign_members_2(lat, lon, nbh, test_df):
    dist_min = 1000000
    bor = ''
    for index, row in tor_bor_lat_lon_mean.iterrows():
        dist = get_distance(row['Latitude'], row['Longitude'], lat, lon)
        if dist < dist_min:
            dist_min = dist
            bor = row['Borough']
    test_df.loc[len(test_df)] = [bor, nbh, lat, lon]

test_df_mean = pd.DataFrame(columns = ['Borough', 'Neighbourhood', 'Latitude', 'Longitude'])
for index, row in tor_bor.iterrows():
    assign_members_2(row['Latitude'], row['Longitude'], row['Neighbourhood'], test_df_mean)
test_df_mean.head()
# Out:
#            Borough                   Neighbourhood   Latitude  Longitude
# 0     East Toronto                     The Beaches  43.676357 -79.293031
# 1     East Toronto    The Danforth West, Riverdale  43.679557 -79.352188
# 2     East Toronto  The Beaches West, India Bazaar  43.668999 -79.315572
# 3     East Toronto                 Studio District  43.659526 -79.340923
# 4  Central Toronto                   Lawrence Park  43.728020 -79.388790

# %% [markdown]
# try on map

# %%
temp_map_2 = folium.Map(location=[tor_lat, tor_lon], zoom_start=11)

for lat, lng, borough in zip(test_df_mean['Latitude'], test_df_mean['Longitude'], test_df_mean['Borough']):
    label = borough
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color=bor_col.get(borough),
#         fill=True,
#         fill_color=bor_col.get(borough),
#         fill_opacity=0.5,
        parse_html=False).add_to(temp_map_2)
    
temp_map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# as we can see - we can use geographical centering to get best k-center
# basicaly it conclusion derived from real world - neigbourhoods are usually grouped in normal way
# for more accurate data i would prefer to use coordinates of each neigborhood and aggregate them to boroughs data

# %% [markdown]
# let'see what we can get from foursquare

# %%
dt_df = tor_bor[data_with_geo['Borough'] == 'Downtown Toronto']
dt_df.head()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#    PostalCode           Borough                Neighbourhood   Latitude  \
# 50        M4W  Downtown Toronto                     Rosedale  43.679563
# 51        M4X  Downtown Toronto  Cabbagetown, St. James Town  43.667967
# 52        M4Y  Downtown Toronto         Church and Wellesley  43.665860
# 53        M5A  Downtown Toronto                 Harbourfront  43.654260
# 54        M5B  Downtown Toronto     Ryerson, Garden District  43.657162
#
#     Longitude
# 50 -79.377529
# 51 -79.367675
# 52 -79.383160
# 53 -79.360636
# 54 -79.378937

# %% [markdown]
# try to find some hospitals

# %%
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&query=hospital'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    43.679563, 
    -79.377529, 
    5000, 
    1000)
            
results = requests.get(url).json()['response']['venues']
results
# Out:
# [{'id': '4ad4c064f964a5206ef820e3',
#   'name': 'The Hospital for Sick Children (SickKids)',
#   'location': {'address': '555 University Ave.',
#    'crossStreet': 'at Gerrard St.',
#    'lat': 43.657498668962646,
#    'lng': -79.3865121609307,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.657498668962646,
#      'lng': -79.3865121609307}],
#    'distance': 2560,
#    'postalCode': 'M5G 1X8',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['555 University Ave. (at Gerrard St.)',
#     'Toronto ON M5G 1X8',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4af0615cf964a5208cdb21e3',
#   'name': "Women's College Hospital",
#   'location': {'address': '76 Grenville St.',
#    'crossStreet': 'at Bay St.',
#    'lat': 43.66149084521543,
#    'lng': -79.38760156543788,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.66149084521543,
#      'lng': -79.38760156543788}],
#    'distance': 2169,
#    'postalCode': 'M5S 1B2',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['76 Grenville St. (at Bay St.)',
#     'Toronto ON M5S 1B2',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4ad4c064f964a52070f820e3',
#   'name': 'Toronto General Hospital',
#   'location': {'address': '190 Elizabeth St',
#    'crossStreet': 'at Gerrard St W',
#    'lat': 43.658762182159144,
#    'lng': -79.38829248908566,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.658762182159144,
#      'lng': -79.38829248908566}],
#    'distance': 2472,
#    'postalCode': 'M5G 2C4',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['190 Elizabeth St (at Gerrard St W)',
#     'Toronto ON M5G 2C4',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4ad4c064f964a5206ff820e3',
#   'name': "St. Michael's Hospital",
#   'location': {'address': '30 Bond St',
#    'crossStreet': 'at Queen St E',
#    'lat': 43.65378419391942,
#    'lng': -79.37780857086182,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65378419391942,
#      'lng': -79.37780857086182}],
#    'distance': 2869,
#    'postalCode': 'M5B 1W8',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['30 Bond St (at Queen St E)',
#     'Toronto ON M5B 1W8',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4af2fb96f964a52086e921e3',
#   'name': 'Toronto Western Hospital',
#   'location': {'address': '399 Bathurst St.',
#    'crossStreet': 'at Dundas St. West',
#    'lat': 43.65343431584569,
#    'lng': -79.40607359183444,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65343431584569,
#      'lng': -79.40607359183444}],
#    'distance': 3707,
#    'postalCode': 'M5T 2S7',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['399 Bathurst St. (at Dundas St. West)',
#     'Toronto ON M5T 2S7',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4b1fbe8af964a5209e2824e3',
#   'name': "Mount Sinai Hospital Women's and Infants' Department",
#   'location': {'address': '700 University Ave., 3rd floor, Ontario Power Generation Building',
#    'crossStreet': 'at College St.',
#    'lat': 43.6596121502049,
#    'lng': -79.39076121745926,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.6596121502049,
#      'lng': -79.39076121745926}],
#    'distance': 2463,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['700 University Ave., 3rd floor, Ontario Power Generation Building (at College St.)',
#     'Toronto ON',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4adb8e3bf964a520f22821e3',
#   'name': 'Michael Garron Hospital',
#   'location': {'address': '825 Coxwell Ave',
#    'crossStreet': 'Mortimer Ave',
#    'lat': 43.689573,
#    'lng': -79.326173,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.689573,
#      'lng': -79.326173}],
#    'distance': 4281,
#    'postalCode': 'M4C 3E7',
#    'cc': 'CA',
#    'city': 'East York',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['825 Coxwell Ave (Mortimer Ave)',
#     'East York ON M4C 3E7',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4ae9bd8af964a520feb521e3',
#   'name': 'Mount Sinai Hospital, Joseph and Wolf Lebovic Centre',
#   'location': {'address': '60 Murray St',
#    'crossStreet': 'College & University',
#    'lat': 43.65824708835551,
#    'lng': -79.39147285590467,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65824708835551,
#      'lng': -79.39147285590467}],
#    'distance': 2625,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['60 Murray St (College & University)',
#     'Toronto ON',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4e3dd18362e19d6109746a06',
#   'name': 'Toronto General Hospital Emergency Room',
#   'location': {'address': '190 Elizabeth St',
#    'crossStreet': 'at Gerrard St W',
#    'lat': 43.65842614181627,
#    'lng': -79.38646209755869,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65842614181627,
#      'lng': -79.38646209755869}],
#    'distance': 2460,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['190 Elizabeth St (at Gerrard St W)',
#     'Toronto ON',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d194941735',
#     'name': 'Emergency Room',
#     'pluralName': 'Emergency Rooms',
#     'shortName': 'Emergency Room',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_ems_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4b7a436df964a520da272fe3',
#   'name': 'Emergency Room: Sunnybrook Hospital',
#   'location': {'address': '2075 Bayview Ave.',
#    'crossStreet': 'at Blythwood Rd.',
#    'lat': 43.720854390795964,
#    'lng': -79.37588969770353,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.720854390795964,
#      'lng': -79.37588969770353}],
#    'distance': 4598,
#    'postalCode': 'M4N 3M5',
#    'cc': 'CA',
#    'city': 'North York',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['2075 Bayview Ave. (at Blythwood Rd.)',
#     'North York ON M4N 3M5',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d194941735',
#     'name': 'Emergency Room',
#     'pluralName': 'Emergency Rooms',
#     'shortName': 'Emergency Room',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_ems_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4c12aaf7a9c220a14d6a549d',
#   'name': 'Bay Cat & Bay Dog Hospital',
#   'location': {'address': '525 King E',
#    'crossStreet': 'Sumach',
#    'lat': 43.655346,
#    'lng': -79.35877,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.655346,
#      'lng': -79.35877}],
#    'distance': 3090,
#    'postalCode': 'M5A 1M3',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['525 King E (Sumach)',
#     'Toronto ON M5A 1M3',
#     'Canada']},
#   'categories': [{'id': '4d954af4a243a5684765b473',
#     'name': 'Veterinarian',
#     'pluralName': 'Veterinarians',
#     'shortName': 'Veterinarians',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '530e123911d277e2ae95c564',
#   'name': 'Toronto General Hospital Parking Lot',
#   'location': {'address': 'Elizabeth Street',
#    'crossStreet': 'College & Elizabeth',
#    'lat': 43.65978,
#    'lng': -79.385699,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65978,
#      'lng': -79.385699}],
#    'distance': 2298,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['Elizabeth Street (College & Elizabeth)',
#     'Toronto ON',
#     'Canada']},
#   'categories': [{'id': '52f2ab2ebcbc57f1066b8b44',
#     'name': 'Auto Garage',
#     'pluralName': 'Auto Garages',
#     'shortName': 'Auto Garage',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4c1681fd5e88c928d83e2466',
#   'name': 'Rosedale Animal Hospital',
#   'location': {'lat': 43.683790777599,
#    'lng': -79.39232832458205,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.683790777599,
#      'lng': -79.39232832458205}],
#    'distance': 1280,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['Toronto ON', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d104941735',
#     'name': 'Medical Center',
#     'pluralName': 'Medical Centers',
#     'shortName': 'Medical',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '58cc204f45005e5834b89895',
#   'name': 'Hospital',
#   'location': {'lat': 43.65319,
#    'lng': -79.37637,
#    'labeledLatLngs': [{'label': 'display', 'lat': 43.65319, 'lng': -79.37637}],
#    'distance': 2937,
#    'postalCode': 'M5C',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['Toronto ON M5C', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d1b3941735',
#     'name': 'Medical School',
#     'pluralName': 'Medical Schools',
#     'shortName': 'Medical School',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4bfef25ee584c928507d6d25',
#   'name': 'Mt. Pleasant-Davisville Veterinary Hospital',
#   'location': {'address': '745 Mount Pleasant Rd',
#    'crossStreet': 'at Eglington Ave. E',
#    'lat': 43.70738302088981,
#    'lng': -79.38993913882214,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.70738302088981,
#      'lng': -79.38993913882214}],
#    'distance': 3253,
#    'postalCode': 'M4S 2N4',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['745 Mount Pleasant Rd (at Eglington Ave. E)',
#     'Toronto ON M4S 2N4',
#     'Canada']},
#   'categories': [{'id': '4d954af4a243a5684765b473',
#     'name': 'Veterinarian',
#     'pluralName': 'Veterinarians',
#     'shortName': 'Veterinarians',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4ad4c064f964a52071f820e3',
#   'name': 'Mount Sinai Hospital',
#   'location': {'address': '600 University Ave',
#    'lat': 43.657701,
#    'lng': -79.389711,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.657701,
#      'lng': -79.389711}],
#    'distance': 2623,
#    'postalCode': 'M5G 1X5',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['600 University Ave', 'Toronto ON M5G 1X5', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '5727b24ecd10fcc48ad9699c',
#   'name': 'Yonge Davenport Pet Hospital',
#   'location': {'lat': 43.674052,
#    'lng': -79.388551,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.674052,
#      'lng': -79.388551}],
#    'distance': 1078,
#    'cc': 'CA',
#    'country': 'Canada',
#    'formattedAddress': ['Canada']},
#   'categories': [{'id': '4d954af4a243a5684765b473',
#     'name': 'Veterinarian',
#     'pluralName': 'Veterinarians',
#     'shortName': 'Veterinarians',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4bce159acc8cd13ac7b6c3cf',
#   'name': 'Dundas Euclid Animal Hospital',
#   'location': {'address': '840 Dundas St. W.',
#    'crossStreet': 'Euclid',
#    'lat': 43.65151776470952,
#    'lng': -79.40998382315287,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65151776470952,
#      'lng': -79.40998382315287}],
#    'distance': 4071,
#    'postalCode': 'M6J 1V5',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['840 Dundas St. W. (Euclid)',
#     'Toronto ON M6J 1V5',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4b6f37e2f964a520e4e42ce3',
#   'name': 'Downtown Animal Hospital',
#   'location': {'address': '579 Church St',
#    'crossStreet': 'Isabella',
#    'lat': 43.667939,
#    'lng': -79.381714,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.667939,
#      'lng': -79.381714}],
#    'distance': 1337,
#    'postalCode': 'M4Y 2E4',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['579 Church St (Isabella)',
#     'Toronto ON M4Y 2E4',
#     'Canada']},
#   'categories': [{'id': '4d954af4a243a5684765b473',
#     'name': 'Veterinarian',
#     'pluralName': 'Veterinarians',
#     'shortName': 'Veterinarians',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '5ae0a6ac86bc497c1bab4079',
#   'name': "Women's College Hospital - Auditorium",
#   'location': {'address': '76 Grenville St',
#    'lat': 43.66161,
#    'lng': -79.387634,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.66161,
#      'lng': -79.387634}],
#    'distance': 2157,
#    'postalCode': 'M5S 1B2',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['76 Grenville St', 'Toronto ON M5S 1B2', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d104941735',
#     'name': 'Medical Center',
#     'pluralName': 'Medical Centers',
#     'shortName': 'Medical',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4fd8e916e4b0a8dbd1d82589',
#   'name': 'Hospital Row',
#   'location': {'lat': 43.653938735433115,
#    'lng': -79.38081484586074,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.653938735433115,
#      'lng': -79.38081484586074}],
#    'distance': 2864,
#    'cc': 'CA',
#    'country': 'Canada',
#    'formattedAddress': ['Canada']},
#   'categories': [],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4dcd6c68e4cd130e164d57c9',
#   'name': 'Yorkville Animal Hospital',
#   'location': {'address': '135 Avenue Rd',
#    'crossStreet': 'at Davenport Rd',
#    'lat': 43.6738567,
#    'lng': -79.3960502,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.6738567,
#      'lng': -79.3960502}],
#    'distance': 1620,
#    'postalCode': 'M5R 2H7',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['135 Avenue Rd (at Davenport Rd)',
#     'Toronto ON M5R 2H7',
#     'Canada']},
#   'categories': [{'id': '4d954af4a243a5684765b473',
#     'name': 'Veterinarian',
#     'pluralName': 'Veterinarians',
#     'shortName': 'Veterinarians',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4b7c11c4f964a520297b2fe3',
#   'name': 'Bathurst-Dupont Animal Hospital',
#   'location': {'address': '1074 Bathurst St',
#    'crossStreet': 'Dupont St.',
#    'lat': 43.67077208965326,
#    'lng': -79.41342375527917,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.67077208965326,
#      'lng': -79.41342375527917}],
#    'distance': 3051,
#    'postalCode': 'M5R 3G9',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['1074 Bathurst St (Dupont St.)',
#     'Toronto ON M5R 3G9',
#     'Canada']},
#   'categories': [{'id': '4d954af4a243a5684765b473',
#     'name': 'Veterinarian',
#     'pluralName': 'Veterinarians',
#     'shortName': 'Veterinarians',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4be09b3498f2a5931fcdc25a',
#   'name': 'Blue Cross Animal Hospital',
#   'location': {'address': '132 Danforth Ave',
#    'lat': 43.67648298673615,
#    'lng': -79.35792405933911,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.67648298673615,
#      'lng': -79.35792405933911}],
#    'distance': 1615,
#    'postalCode': 'M4K 1N1',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['132 Danforth Ave', 'Toronto ON M4K 1N1', 'Canada']},
#   'categories': [{'id': '4d954af4a243a5684765b473',
#     'name': 'Veterinarian',
#     'pluralName': 'Veterinarians',
#     'shortName': 'Veterinarians',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '5baa5e65135b39002cbf29a4',
#   'name': "Sutherland Chan Clinic - Women's College Hospital",
#   'location': {'lat': 43.661514,
#    'lng': -79.387085,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.661514,
#      'lng': -79.387085}],
#    'distance': 2151,
#    'postalCode': 'M5S 1B2',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['Toronto ON M5S 1B2', 'Canada']},
#   'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#     'name': 'Massage Studio',
#     'pluralName': 'Massage Studios',
#     'shortName': 'Massage Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4cdf5495f8cdb1f738339112',
#   'name': "St Michael's Hospital Medical Imaging",
#   'location': {'address': '30 Bond St.',
#    'lat': 43.65368444376282,
#    'lng': -79.37870569300675,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65368444376282,
#      'lng': -79.37870569300675}],
#    'distance': 2882,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['30 Bond St.', 'Toronto ON', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d104941735',
#     'name': 'Medical Center',
#     'pluralName': 'Medical Centers',
#     'shortName': 'Medical',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '521b3e7f11d27fbcf4f28be8',
#   'name': 'Toronto Western Hospital Fracture Clinic',
#   'location': {'lat': 43.664401425734965,
#    'lng': -79.38850141455815,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.664401425734965,
#      'lng': -79.38850141455815}],
#    'distance': 1905,
#    'cc': 'CA',
#    'country': 'Canada',
#    'formattedAddress': ['Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4db09bf70437a93f7f770755',
#   'name': 'Wellesley Animal Hospital',
#   'location': {'address': '535 Yonge St',
#    'lat': 43.66494103924063,
#    'lng': -79.38458123431751,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.66494103924063,
#      'lng': -79.38458123431751}],
#    'distance': 1723,
#    'postalCode': 'M4Y 1Y5',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['535 Yonge St', 'Toronto ON M4Y 1Y5', 'Canada']},
#   'categories': [{'id': '4d954af4a243a5684765b473',
#     'name': 'Veterinarian',
#     'pluralName': 'Veterinarians',
#     'shortName': 'Veterinarians',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4bdb18fc3904a5935bbe489e',
#   'name': 'Davenport Road Animal Hospital',
#   'location': {'address': '303 Davenport Rd.',
#    'lat': 43.674605,
#    'lng': -79.400694,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.674605,
#      'lng': -79.400694}],
#    'distance': 1944,
#    'postalCode': 'M5R 1K5',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['303 Davenport Rd.', 'Toronto ON M5R 1K5', 'Canada']},
#   'categories': [{'id': '4d954af4a243a5684765b473',
#     'name': 'Veterinarian',
#     'pluralName': 'Veterinarians',
#     'shortName': 'Veterinarians',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4ee201b9d5fbcceafebf2847',
#   'name': 'Sleep Medicine and Research Rounds at Toronto General Hospital',
#   'location': {'address': '200 Elizabeth St.',
#    'crossStreet': 'Ground Floor 025/026',
#    'lat': 43.65911684437622,
#    'lng': -79.3883228302002,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65911684437622,
#      'lng': -79.3883228302002}],
#    'distance': 2436,
#    'postalCode': 'M5G 2C4',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['200 Elizabeth St. (Ground Floor 025/026)',
#     'Toronto ON M5G 2C4',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4dfe79a0c65b677898931b89',
#   'name': 'Bayview Animal Hospital',
#   'location': {'address': '1234 bayview ave',
#    'crossStreet': 'Bayview and moore',
#    'lat': 43.69700755659606,
#    'lng': -79.37203334241512,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.69700755659606,
#      'lng': -79.37203334241512}],
#    'distance': 1991,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['1234 bayview ave (Bayview and moore)',
#     'Toronto ON',
#     'Canada']},
#   'categories': [{'id': '4d954af4a243a5684765b473',
#     'name': 'Veterinarian',
#     'pluralName': 'Veterinarians',
#     'shortName': 'Veterinarians',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4be2b974f07b0f47e6fff543',
#   'name': 'Mt Sinai Hospital; Rheumatology Clinic',
#   'location': {'lat': 43.6580952649394,
#    'lng': -79.39125038998642,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.6580952649394,
#      'lng': -79.39125038998642}],
#    'distance': 2632,
#    'cc': 'CA',
#    'country': 'Canada',
#    'formattedAddress': ['Canada']},
#   'categories': [{'id': '4bf58dd8d48988d177941735',
#     'name': "Doctor's Office",
#     'pluralName': "Doctor's Offices",
#     'shortName': "Doctor's Office",
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4f8499a5e4b07c5cea098474',
#   'name': 'CICU Toronto General Hospital',
#   'location': {'address': '190 Elizabeth Street',
#    'lat': 43.658716988295915,
#    'lng': -79.38677501623404,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.658716988295915,
#      'lng': -79.38677501623404}],
#    'distance': 2437,
#    'postalCode': 'M5G 2C4',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['190 Elizabeth Street',
#     'Toronto ON M5G 2C4',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '59525287c4df1d49b8a1e677',
#   'name': "St Michael's Hospital - Gastroenterology",
#   'location': {'lat': 43.653653,
#    'lng': -79.378081,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.653653,
#      'lng': -79.378081}],
#    'distance': 2884,
#    'postalCode': 'M5B 1W8',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['Toronto ON M5B 1W8', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4bcc71b3937ca5934e11ab92',
#   'name': "Woomen's College Hospital - Burton Hall",
#   'location': {'lat': 43.662338,
#    'lng': -79.387238,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.662338,
#      'lng': -79.387238}],
#    'distance': 2070,
#    'cc': 'CA',
#    'country': 'Canada',
#    'formattedAddress': ['Canada']},
#   'categories': [{'id': '4bf58dd8d48988d104941735',
#     'name': 'Medical Center',
#     'pluralName': 'Medical Centers',
#     'shortName': 'Medical',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4e1da414483bbda4181d1871',
#   'name': "Women's College Hospital, Boardroom",
#   'location': {'address': '76 Grenville',
#    'lat': 43.661369761309004,
#    'lng': -79.3876712079196,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.661369761309004,
#      'lng': -79.3876712079196}],
#    'distance': 2183,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['76 Grenville', 'Toronto ON', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '5dceac76e466fd000857f7aa',
#   'name': "Women's College Hospital Diagnostics 4Th Floor",
#   'location': {'address': '74 Grenville',
#    'lat': 43.661613,
#    'lng': -79.38791,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.661613,
#      'lng': -79.38791}],
#    'distance': 2165,
#    'postalCode': 'M5S 1B2',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['74 Grenville', 'Toronto ON M5S 1B2', 'Canada']},
#   'categories': [{'id': '4f4531b14b9074f6e4fb0103',
#     'name': 'Medical Lab',
#     'pluralName': 'Medical Labs',
#     'shortName': 'Medical Lab',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '5239b5e1bce69a9b5af47d26',
#   'name': "Women's College Hospital Pharmacy",
#   'location': {'address': '77 Grenville St',
#    'crossStreet': 'Bay St. & College St.',
#    'lat': 43.661181469774355,
#    'lng': -79.38701391220093,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.661181469774355,
#      'lng': -79.38701391220093}],
#    'distance': 2184,
#    'postalCode': 'M5S 1B3',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['77 Grenville St (Bay St. & College St.)',
#     'Toronto ON M5S 1B3',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d10f951735',
#     'name': 'Pharmacy',
#     'pluralName': 'Pharmacies',
#     'shortName': 'Pharmacy',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4c176aa1216fc9b644578f96',
#   'name': "410 Health Centre (St. Michael's Hospital)",
#   'location': {'address': '410 Sherbourne',
#    'crossStreet': 'Carlton',
#    'lat': 43.664831527209806,
#    'lng': -79.37405031717384,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.664831527209806,
#      'lng': -79.37405031717384}],
#    'distance': 1663,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['410 Sherbourne (Carlton)', 'Toronto ON', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4e04b200e4cd92cb899e3e55',
#   'name': "Women's College Hospital Team 4",
#   'location': {'address': 'Grosvenor',
#    'crossStreet': 'Bay',
#    'lat': 43.66157573126396,
#    'lng': -79.38879830783908,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.66157573126396,
#      'lng': -79.38879830783908}],
#    'distance': 2198,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['Grosvenor (Bay)', 'Toronto ON', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d177941735',
#     'name': "Doctor's Office",
#     'pluralName': "Doctor's Offices",
#     'shortName': "Doctor's Office",
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '5615508c498e81840497746b',
#   'name': "St. Michael's Hospital - Glaucoma & Nerve Protection",
#   'location': {'lat': 43.653703,
#    'lng': -79.37949,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.653703,
#      'lng': -79.37949}],
#    'distance': 2883,
#    'cc': 'CA',
#    'country': 'Canada',
#    'formattedAddress': ['Canada']},
#   'categories': [{'id': '522e32fae4b09b556e370f19',
#     'name': 'Eye Doctor',
#     'pluralName': 'Eye Doctors',
#     'shortName': 'Eye Doctor',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '51827e19498ef0bdd14d72c5',
#   'name': 'Mt.sinai Hospital',
#   'location': {'lat': 43.663605,
#    'lng': -79.394005,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.663605,
#      'lng': -79.394005}],
#    'distance': 2217,
#    'cc': 'CA',
#    'country': 'Canada',
#    'formattedAddress': ['Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '56eaa40a498eff8f02e378a0',
#   'name': 'Mount Sinai Hospital Food Court',
#   'location': {'lat': 43.65752,
#    'lng': -79.390493,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65752,
#      'lng': -79.390493}],
#    'distance': 2666,
#    'cc': 'CA',
#    'country': 'Canada',
#    'formattedAddress': ['Canada']},
#   'categories': [{'id': '4bf58dd8d48988d120951735',
#     'name': 'Food Court',
#     'pluralName': 'Food Courts',
#     'shortName': 'Food Court',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '53a9d10b498e3beb4d2580b1',
#   'name': "Sick Kids Hospital Farmer's Market",
#   'location': {'crossStreet': 'University Ave & Gerrard St.',
#    'lat': 43.657588,
#    'lng': -79.389321,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.657588,
#      'lng': -79.389321}],
#    'distance': 2624,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['University Ave & Gerrard St.',
#     'Toronto ON',
#     'Canada']},
#   'categories': [{'id': '52f2ab2ebcbc57f1066b8b1c',
#     'name': 'Fruit & Vegetable Store',
#     'pluralName': 'Fruit & Vegetable Stores',
#     'shortName': 'Fruit & Vegetable Store',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '516eeef8498e01be6d9b842d',
#   'name': 'Hematology Clinic South (Princess Msrgaret Hospital)',
#   'location': {'address': '610 University Ave.',
#    'crossStreet': 'University & Murray St.',
#    'lat': 43.658671,
#    'lng': -79.390153,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.658671,
#      'lng': -79.390153}],
#    'distance': 2538,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['610 University Ave. (University & Murray St.)',
#     'Toronto ON',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d177941735',
#     'name': "Doctor's Office",
#     'pluralName': "Doctor's Offices",
#     'shortName': "Doctor's Office",
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4e5e3506fa768fe5f2c3ecc1',
#   'name': 'St Michael Hospital',
#   'location': {'address': '50 Bond street',
#    'lat': 43.654023682719696,
#    'lng': -79.3787363936361,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.654023682719696,
#      'lng': -79.3787363936361}],
#    'distance': 2844,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['50 Bond street', 'Toronto ON', 'Canada']},
#   'categories': [],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4e8d964ff9f4d4b14d2c232e',
#   'name': "Women's College Hospital Family Practice",
#   'location': {'address': '77 Grenville St.',
#    'crossStreet': 'at Bay St',
#    'lat': 43.6619099467916,
#    'lng': -79.38712689621299,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.6619099467916,
#      'lng': -79.38712689621299}],
#    'distance': 2111,
#    'postalCode': 'M5S 1B3',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['77 Grenville St. (at Bay St)',
#     'Toronto ON M5S 1B3',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d177941735',
#     'name': "Doctor's Office",
#     'pluralName': "Doctor's Offices",
#     'shortName': "Doctor's Office",
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '505b049de4b0078ffd2a283a',
#   'name': 'Toronto General Hospital Audio Visual Services Office',
#   'location': {'address': '200 Elizabeth Street Ground Floor Norman Urquhart Room 119',
#    'lat': 43.65902109873273,
#    'lng': -79.38951764528235,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65902109873273,
#      'lng': -79.38951764528235}],
#    'distance': 2482,
#    'postalCode': 'M5G 2C4',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['200 Elizabeth Street Ground Floor Norman Urquhart Room 119',
#     'Toronto ON M5G 2C4',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d124941735',
#     'name': 'Office',
#     'pluralName': 'Offices',
#     'shortName': 'Office',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4d5d30d39c31b60c12f8bcee',
#   'name': 'Rehab and wellbeing center at mount sinai hospital',
#   'location': {'address': '600 university avenue',
#    'lat': 43.6598,
#    'lng': -79.38868,
#    'labeledLatLngs': [{'label': 'display', 'lat': 43.6598, 'lng': -79.38868}],
#    'distance': 2376,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['600 university avenue', 'Toronto ON', 'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d196941735',
#     'name': 'Hospital',
#     'pluralName': 'Hospitals',
#     'shortName': 'Hospital',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False},
#  {'id': '4ae1d932f964a520ea8721e3',
#   'name': 'Holland Bloorview Kids Rehabilitation Hospital',
#   'location': {'address': '150 Kilgour Rd.',
#    'crossStreet': 'at Bayview Ave.',
#    'lat': 43.71829338235304,
#    'lng': -79.37363230805988,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.71829338235304,
#      'lng': -79.37363230805988}],
#    'distance': 4322,
#    'postalCode': 'M4G 1R8',
#    'cc': 'CA',
#    'city': 'North York',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['150 Kilgour Rd. (at Bayview Ave.)',
#     'North York ON M4G 1R8',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d104941735',
#     'name': 'Medical Center',
#     'pluralName': 'Medical Centers',
#     'shortName': 'Medical',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1581337679',
#   'hasPerk': False}]

# %%
hosp_map = folium.Map(location=[tor_lat, tor_lon], zoom_start=11)

for venue in results:
    label = venue['name']
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [venue['location']['lat'], venue['location']['lng']],
        radius=2,
        popup=label,
        color='red',
#         fill=True,
#         fill_color=bor_col.get(borough),
#         fill_opacity=0.5,
        parse_html=False).add_to(hosp_map)
    
hosp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# wrap call into function

# %%
def call_api(lat, lon, radius = 1000, limit = 100):
    url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        lon, 
        radius, 
        limit)
            
    return(requests.get(url).json()['response']['venues'])

# %% [markdown]
# get data for Downtown Toronto

# %%
dt_venues_df = pd.DataFrame(columns = ['Name', 'Category', 'Neighbourhood'])
for index, row in dt_df.iterrows():
    responces = call_api(row['Latitude'], row['Longitude'])
    for resp in responces:
        cat = resp['categories']
        cat_name = 'Unknown'
        if len(cat) == 0:
            cat_name = 'Unknown'
        else:
            cat_name = cat[0]['name']
        dt_venues_df.loc[len(dt_venues_df)] = [resp['name'], cat_name, row['Neighbourhood']]
dt_venues_df.head()
# Out:
#                               Name                                  Category  \
# 0                  Mooredale House                                  Building
# 1     Park Drive Reservation Lands                                      Park
# 2                   10 Lamport Ave  Residential Building (Apartment / Condo)
# 3                   Milkman's Lane                                     Trail
# 4  Le Germain Hotel Toronto Mercer                                     Hotel
#
#   Neighbourhood
# 0      Rosedale
# 1      Rosedale
# 2      Rosedale
# 3      Rosedale
# 4      Rosedale

# %%
dt_venues_df.shape
# Out:
# (1770, 3)

# %% [markdown]
# peek into receieved data

# %%
dt_venues_df[dt_venues_df['Category'] != 'Unknown'].groupby(['Category','Neighbourhood']).size().reset_index().rename(columns = {0: 'count'}).sort_values(by='count', ascending=False).head(20)
# Out:
#                                      Category  \
# 501                                  Hospital
# 702                                    Office
# 693                                    Office
# 697                                    Office
# 694                                    Office
# 687                                    Office
# 802  Residential Building (Apartment / Condo)
# 703                                    Office
# 7                                Airport Gate
# 444                       Government Building
# 695                                    Office
# 805  Residential Building (Apartment / Condo)
# 686                                    Office
# 253                               College Lab
# 926                    Thrift / Vintage Store
# 700                                    Office
# 691                                    Office
# 121                                  Building
# 804  Residential Building (Apartment / Condo)
# 245                         College Classroom
#
#                                          Neighbourhood  count
# 501                                 Central Bay Street     24
# 702                                     St. James Town     21
# 693                     Commerce Court, Victoria Hotel     21
# 697                                       Harbourfront     17
# 694           Design Exchange, Toronto Dominion Centre     17
# 687                                        Berczy Park     17
# 802                               Church and Wellesley     15
# 703                    Stn A PO Boxes 25 The Esplanade     12
# 7    CN Tower, Bathurst Quay, Island airport, Harbo...     12
# 444                                       Queen's Park     12
# 695             First Canadian Place, Underground city     11
# 805                                           Rosedale     11
# 686                           Adelaide, King, Richmond     10
# 253                           Ryerson, Garden District      9
# 926          Chinatown, Grange Park, Kensington Market      9
# 700                                           Rosedale      9
# 691                                           Christie      9
# 121                                        Berczy Park      8
# 804  Harbourfront East, Toronto Islands, Union Station      8
# 245                     Harbord, University of Toronto      7
